# %%
import os
from pathlib import Path

import numpy as np
import pandas as pd
import xarray as xr

from metpy.calc import wind_speed
from metpy.calc import wind_direction 
from metpy.units import units

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams.update({'font.size' : 18})

# %% [markdown]
# # About
# __Author:__ Pat McCornack
# __Date:__ 04/11/25
# __Purpose:__ Uses extracted netcdfs for standard meteorological variables and Chris Still met station data to evaluate WRF's performance.

# %% [markdown]
# # Functions

# %% [markdown]
# # Load/Process Data

# %%
root_dir = Path().resolve().parents[0]
met_df_fpath = root_dir /  'data' / 'weather-station' / 'combined-sites.csv'
met_coords_fpath = root_dir / 'data' / 'weather-station' / 'sci-stations.csv'

met_coords = pd.read_csv(met_coords_fpath)  # Info about the weather stations
met_coords = met_coords.loc[~met_coords['station'].isin(['eend', 'eenc', 'crat', 'pozo-smo2', 'pozo-smo1'])]  # Drop irrelevant sites

# %% [markdown]
# ## Process Weather Station Data

# %%
# Set up met_df
met_df = pd.read_csv(met_df_fpath, index_col=0)
met_df['time (PST)'] = pd.to_datetime(met_df['time (PST)'])

met_df = met_df[['site', 'time (PST)', 'air temperature (C)', 'relative humidity (%)', 'wind speed (m/s)', 'wind direction (deg)']]
met_df = met_df.loc[~met_df['site'].isin(['eend', 'eenc', 'crat', 'pozo-smo2', 'pozo-smo1'])]  # Drop irrelevant sites

met_df.describe()
# Out:
#                           time (PST)  air temperature (C)  \
# count                         622499        603912.000000
# mean   2006-11-14 01:20:39.554279936            14.174732
# min              2003-12-19 16:00:00             0.850000
# 25%              2005-05-06 22:15:00            10.780000
# 50%              2006-05-21 02:00:00            13.150000
# 75%              2008-05-15 03:07:30            16.799999
# max              2011-10-01 23:00:00           111.400000
# std                              NaN             4.917584
#
#        relative humidity (%)  wind speed (m/s)  wind direction (deg)
# count          613093.000000     582516.000000         574226.000000
# mean               69.607999          1.679329            225.004033
# min                 0.000000          0.000000              0.000000
# 25%                52.110000          0.540000            122.300000
# 50%                80.800000          1.432000            286.399990
# 75%                95.750000          2.555000            317.800000
# max               100.000000         16.120000            677.000000
# std                31.357300          1.431682            112.578061

# %% [markdown]
# __Maximum outliers__
# Air temperatures maximum is 111.4 - which is impossible. There's several rows with this value, and these are all set to NAN.
# Similarly, there's a recorded wind direction value of over 360, this is also set to nan

# %%
# Handle outliers

# Air temperature over 50C is unlikely
met_df.loc[met_df['air temperature (C)'] > 50] # Values are all 111.4 -> set to NaN
met_df.loc[met_df['air temperature (C)'] > 50, 'air temperature (C)'] = np.nan

# Can't have wind direction over 360
met_df.loc[met_df['wind direction (deg)'] > 360, 'wind direction (deg)'] = np.nan

# %% [markdown]
# __Air Temperature Minimum Outliers__
# Ther's a bunch of air temperature observations from June 17, 2011 for Sauces Canyon. The low recorded by the RAWS stations for this day was 50*F, so these are probably bad.

# %%
met_df.loc[(met_df['air temperature (C)'] < 2) & (met_df['time (PST)'].dt.month == 6), 'air temperature (C)'] = np.nan

# %%
met_df.describe()
# Out:
#                           time (PST)  air temperature (C)  \
# count                         622499        603889.000000
# mean   2006-11-14 01:20:39.554279936            14.174674
# min              2003-12-19 16:00:00             1.847000
# 25%              2005-05-06 22:15:00            10.780000
# 50%              2006-05-21 02:00:00            13.150000
# 75%              2008-05-15 03:07:30            16.799999
# max              2011-10-01 23:00:00            40.670000
# std                              NaN             4.912346
#
#        relative humidity (%)  wind speed (m/s)  wind direction (deg)
# count          613093.000000     582516.000000         574225.000000
# mean               69.607999          1.679329            225.003246
# min                 0.000000          0.000000              0.000000
# 25%                52.110000          0.540000            122.300000
# 50%                80.800000          1.432000            286.399990
# 75%                95.750000          2.555000            317.800000
# max               100.000000         16.120000            360.000000
# std                31.357300          1.431682            112.576579

# %%
# Set multiindex 
sites = met_df['site'].unique().tolist()
met_df = met_df.set_index(['site', 'time (PST)'])

# %% [markdown]
# # QC

# %%
temp_df = met_df.loc['crak']
temp_df = temp_df.dropna(subset='air temperature (C)')
temp_df['relative humidity (%)'].plot()
# Out:
# <Axes: xlabel='time (PST)'>

# %%
temp_df.loc[temp_df['relative humidity (%)'] == 0]
# Out:
#                      air temperature (C)  relative humidity (%)  \
# time (PST)
# 2005-08-23 11:30:00            25.559999                    0.0
# 2005-08-23 13:00:00            24.010000                    0.0
# 2005-08-23 13:15:00            23.240000                    0.0
# 2005-08-23 13:30:00            23.240000                    0.0
# 2005-08-23 13:45:00            23.629999                    0.0
# ...                                  ...                    ...
# 2006-07-19 00:15:00            16.000000                    0.0
# 2006-07-19 00:30:00            16.000000                    0.0
# 2006-07-19 00:45:00            16.000000                    0.0
# 2006-07-19 18:15:00            18.660000                    0.0
# 2006-07-19 18:30:00            18.280001                    0.0
#
#                      wind speed (m/s)  wind direction (deg)
# time (PST)
# 2005-08-23 11:30:00              2.78             123.50000
# 2005-08-23 13:00:00              3.15             127.80000
# 2005-08-23 13:15:00              3.90             124.90000
# 2005-08-23 13:30:00              3.90             126.40000
# 2005-08-23 13:45:00              3.90             127.80000
# ...                               ...                   ...
# 2006-07-19 00:15:00              0.19             263.89999
# 2006-07-19 00:30:00              0.19             263.89999
# 2006-07-19 00:45:00              0.19             263.89999
# 2006-07-19 18:15:00              2.41             297.60001
# 2006-07-19 18:30:00              1.86             299.00000
#
# [16682 rows x 4 columns]

# %%
met_df.loc[met_df['relative humidity (%)'] == 0]
# Out:
#                           air temperature (C)  relative humidity (%)  \
# site time (PST)
# wrdg 2004-04-05 14:30:00                  NaN                    0.0
#      2004-04-05 14:45:00                  NaN                    0.0
#      2004-04-05 15:00:00                  NaN                    0.0
#      2004-04-05 15:15:00                  NaN                    0.0
#      2004-04-05 15:30:00                  NaN                    0.0
# ...                                       ...                    ...
# erdg 2006-10-25 15:45:00            20.570000                    0.0
#      2006-10-25 16:00:00            20.570000                    0.0
#      2006-10-25 16:15:00            19.420000                    0.0
#      2006-10-25 16:30:00            19.809999                    0.0
#      2006-10-25 16:45:00            19.420000                    0.0
#
#                           wind speed (m/s)  wind direction (deg)
# site time (PST)
# wrdg 2004-04-05 14:30:00              0.00              0.000000
#      2004-04-05 14:45:00              0.00              0.000000
#      2004-04-05 15:00:00              0.00              0.000000
#      2004-04-05 15:15:00              0.00              0.000000
#      2004-04-05 15:30:00              0.00              0.000000
# ...                                    ...                   ...
# erdg 2006-10-25 15:45:00              2.04             50.500000
#      2006-10-25 16:00:00              1.86              2.800000
#      2006-10-25 16:15:00              2.04            352.399990
#      2006-10-25 16:30:00              1.48             50.500000
#      2006-10-25 16:45:00              1.30             16.799999
#
# [32066 rows x 4 columns]

# %%
for idx, row in met_df.iterrows():
    if (row['wind speed (m/s)'] == 0 and 
        row['wind gust (m/s)'] == 0 and 
        row['wind direction (deg)'] == 0):
        met_df.at[idx, 'wind speed (m/s)'] = np.nan
        met_df.at[idx, 'wind gust (m/s)'] = np.nan
        met_df.at[idx, 'wind direction (deg)'] = np.nan
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/miniconda3/envs/wrf/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'wind gust (m/s)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 3
#       1 for idx, row in met_df.iterrows():
#       2     if (row['wind speed (m/s)'] == 0 and
# ----> 3         row['wind gust (m/s)'] == 0 and
#       4         row['wind direction (deg)'] == 0):
#       5         met_df.at[idx, 'wind speed (m/s)'] = np.nan
#       6         met_df.at[idx, 'wind gust (m/s)'] = np.nan
#
# File /opt/miniconda3/envs/wrf/lib/python3.12/site-packages/pandas/core/series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File /opt/miniconda3/envs/wrf/lib/python3.12/site-packages/pandas/core/series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File /opt/miniconda3/envs/wrf/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'wind gust (m/s)'

# %% [markdown]
# ## Process WRF data

# %%
# Extract dataframe from netcdfs using site coords
first_pass = True
for var, fpath in wrf_dict.items():  # For each variable
    var_df = pd.DataFrame()
    for i, row in met_coords.iterrows():  # For each station
        lat = row['latitude']
        lon = row['longitude']
        ds = xr.open_dataarray(wrf_dict[var])
        station_ds = ds.sel(lat=lat, lon=lon, method='nearest')
        station_df = station_ds.to_dataframe(name=var).reset_index()[['time', var]]
        station_df['site'] = row['station']

        station_df['time'] = pd.to_datetime(station_df['time'])
        station_df['time'] = station_df['time'] - pd.to_timedelta(1, unit='h')  # PDT to PST
        station_df = station_df.rename({'time' : 'time (PST)'}, axis=1)
        station_df = station_df.set_index(['site', 'time (PST)'])

        var_df = pd.concat([var_df, station_df])

    # Create single df with all variables
    if first_pass == True:
        wrf_df = var_df
    else:
        wrf_df = pd.merge(wrf_df, var_df, how='inner', left_index=True, right_index=True)
    
    first_pass = False

wrf_df.describe()
# Out:
#                  RH2             T2            U10            V10
# count  585179.000000  585179.000000  585179.000000  585179.000000
# mean       69.397964     290.633636       2.342463      -1.729972
# std        22.255562       5.408674       2.931606       2.346412
# min         2.387302       0.000000     -15.134946     -12.375834
# 25%        54.739790     286.929840       0.546338      -3.280115
# 50%        71.825264     289.977692       2.611226      -1.616169
# 75%        87.442387     293.718628       4.293668      -0.178745
# max       100.000000     313.371521      14.015853       7.244581

# %%
# Convert K to C
wrf_df['T2'] = wrf_df['T2'] - 273
wrf_df.loc[wrf_df['T2'] == -273] = np.nan  # Handle bad values

wrf_df['T2'].describe()
# Out:
# count    585144.000000
# mean         17.650930
# std           4.919634
# min           5.605377
# 25%          13.930588
# 50%          16.978027
# 75%          20.719032
# max          40.371521
# Name: T2, dtype: float64

# %%
# Get wind speed/direction from components
u = wrf_df['U10'].values * units('m/s')
v = wrf_df['V10'].values * units('m/s')
wrf_df['wind_spd'] = wind_speed(u,v)
wrf_df['wind_dir'] = wind_direction(u, v, convention='from')
wrf_df = wrf_df.drop(['U10', 'V10'], axis=1)

wrf_df[['wind_spd', 'wind_dir']].describe()
# Out:
#             wind_spd       wind_dir
# count  585144.000000  585144.000000
# mean        4.094111     258.236786
# std         2.411633      83.209549
# min         0.007292       0.002151
# 25%         2.316300     227.048431
# 50%         3.611422     296.751709
# 75%         5.553937     311.518951
# max        16.061771     359.999207

# %%
# Rename WRF columns
new_cols = []
for col in list(wrf_df.columns):
    new_cols.append(col + '_wrf')

wrf_df.columns = new_cols
wrf_df.head()
# Out:
#                             RH2_wrf     T2_wrf  wind_spd_wrf  wind_dir_wrf
# site time (PST)
# cair 1996-05-31 16:00:00  67.323349  16.843048      5.707997    292.702515
#      1996-05-31 17:00:00  70.684212  16.279541      5.039712    293.075470
#      1996-05-31 18:00:00  73.011337  15.763458      4.491889    293.207214
#      1996-05-31 19:00:00  76.270844  14.929565      3.399316    290.956421
#      1996-05-31 20:00:00  80.533516  14.153656      2.519886    288.491150

# %%
# Join dataframes
join_df = pd.concat([met_df, wrf_df], join='inner', axis=1)
join_df.head()
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[179], line 2
#       1 # Join dataframes
# ----> 2 join_df = pd.concat([met_df, wrf_df], join='inner', axis=1)
#       3 join_df.head()
#
# File /opt/miniconda3/envs/wrf/lib/python3.12/site-packages/pandas/core/reshape/concat.py:395, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     copy = False
#     382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#    (...)
#     392     sort=sort,
#     393 )
# --> 395 return op.get_result()
#
# File /opt/miniconda3/envs/wrf/lib/python3.12/site-packages/pandas/core/reshape/concat.py:680, in _Concatenator.get_result(self)
#     678         obj_labels = obj.axes[1 - ax]
#     679         if not new_labels.equals(obj_labels):
# --> 680             indexers[ax] = obj_labels.get_indexer(new_labels)
#     682     mgrs_indexers.append((obj._mgr, indexers))
#     684 new_data = concatenate_managers(
#     685     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     686 )
#
# File /opt/miniconda3/envs/wrf/lib/python3.12/site-packages/pandas/core/indexes/base.py:3885, in Index.get_indexer(self, target, method, limit, tolerance)
#    3882 self._check_indexing_method(method, limit, tolerance)
#    3884 if not self._index_as_unique:
# -> 3885     raise InvalidIndexError(self._requires_unique_msg)
#    3887 if len(target) == 0:
#    3888     return np.array([], dtype=np.intp)
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects
